# %%
# imports
import pandas as pd
from pycaret.classification import *

# %%
# load and choose categoricals
df = pd.read_excel('./data/heart.xlsx', engine='openpyxl')
cats_ = ['sex_M_F', 'chest_pain_value', 'ECG_value', 'ST_slope_peak', 'defect_diag']
df.head(5)
# Out:
#    age_yr  sex_M_F  chest_pain_value  resting_BP_mm_Hg  cholesterol_mg_dl  \
# 0      70        1                 4               130                322
# 1      67        0                 3               115                564
# 2      57        1                 2               124                261
# 3      64        1                 4               128                263
# 4      74        0                 2               120                269
#
#    fasting_blood_sugar_high  ECG_value  max_HR  exercise_angina  \
# 0                         0          2     109                0
# 1                         0          2     160                0
# 2                         0          0     141                0
# 3                         0          0     105                1
# 4                         0          2     121                1
#
#    ST_depresssion_exercise  ST_slope_peak  number_vessels_involved  \
# ...

# %%
#setup target
ex = setup(df, target='heart_disease', categorical_features=cats_)
# Out:
# <style type="text/css">
# #T_d891e_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d891e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d891e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d891e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d891e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d891e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d891e_row0_col1" class="data row0 col1" >8683</td>
#     </tr>
#     <tr>
#       <th id="T_d891e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d891e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d891e_row1_col1" class="data row1 col1" >heart_disease</td>
#     </tr>
#     <tr>
#       <th id="T_d891e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# find "best model"
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_df183 th {
#   text-align: left;
# }
# ...
